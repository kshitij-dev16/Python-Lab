# %% [markdown]
# # Experiment 4
# ## Name : Kshitij Dalvi
# ## PRN : 25070123066
# ## Batch : A-3

# %%
# Python Tuples
# Create Tuple and access tuple items
mytuple = ("Zebra", "Lion", "Rhino","Elephant")
print(mytuple)
print(mytuple[1])
# Out:
# ('Zebra', 'Lion', 'Rhino', 'Elephant')
# Lion

# %%
mytuple = ("Zebra", "Lion", "Rhino","Elephant")
mytuple[1]="Tiger"
print(mytuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-687193673.py in <cell line: 0>()
#       1 mytuple = ("Zebra", "Lion", "Rhino","Elephant")
# ----> 2 mytuple[1]="Tiger"
#       3 print(mytuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
mytuple = ("Zebra", "Lion", "Rhino","Elephant")
mytuple.append("Tiger")
print(mytuple)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2110595267.py in <cell line: 0>()
#       1 mytuple = ("Zebra", "Lion", "Rhino","Elephant")
# ----> 2 mytuple.append("Tiger")
#       3 print(mytuple)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# Add to a tuple
mytuple = ("Zebra", "Lion", "Rhino","Elephant")
a = ("Tiger",)
mytuple += a
print(mytuple)
# Out:
# ('Zebra', 'Lion', 'Rhino', 'Elephant', 'Tiger')

# %%
# Slicing of a tuple
mytuple = ("Zebra", "Lion", "Rhino","Elephant")
print(mytuple[2:5])
print(mytuple[-4:-2])
print(mytuple[-4:])
tuple1=[20,30,50,60,40,10,70]
print(tuple1[1:3])
print(tuple1[1:3:1])
print(tuple1[1:5:2])
print(tuple1[1:4:3])
print(tuple1[6:4:-2])
print(tuple1[4:6:-1])
print(tuple1[-2:-4:-2])
# Out:
# ('Rhino', 'Elephant')
# ('Zebra', 'Lion')
# ('Zebra', 'Lion', 'Rhino', 'Elephant')

# %%
'''Students exam result stored in a tuple with three fixed field
Subject Name, Marks Obtained, and Grade'''
result = ("EDA",79,"A")
subject, marks, grade = result
print("Subject name :",subject)
print("Marks obtained :",marks)
print("Grade :",grade)
if result[1]>=75:
  print("Distinction")
# Out:
# Subject name : EDA
# Marks obtained : 79
# Grade : A
# Distinction

# %%
'''Organization records a employee's daily attendance for a week using a tuple
P for present and A for absent'''
attendance=("P","P","P","A","A","P")
print("Total number of present days :",attendance.count("P"))
print("Total number of absent days :",attendance.count("A"))
if attendance.count("A")>0:
  print("Absent atleast once)"
# Out:
# Total number of present days : 4
# Total number of absent days : 2
# Absent atleast once
