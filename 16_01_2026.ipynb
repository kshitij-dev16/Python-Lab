# %% [markdown]
# <a href="https://colab.research.google.com/github/kshitij-dev16/Python-Lab/blob/main/16_01_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First Python Program/ String
print("Hello, Welcome to Python Programming")

# %%
a = "Hello"
print(a)

# %%
# Comments
#This is a comment.
print("Hello, World!")

# %%
# Many Statements
print("Hello World!")
print("Have a good day.")
print("Learning Python is fun!")

# %%
print("Hello"); print("How are you?"); print("Bye bye!")

# %%
print("Python is fun!") print("Really!")
# Out:
#   File "/tmp/ipython-input-2531607073.py", line 1
#     print("Python is fun!") print("Really!")
#                             ^
# SyntaxError: invalid syntax

# %%
print("This will work!")
print('This will also work!')

# %%
print(This will cause an error)
# Out:
#   File "/tmp/ipython-input-2830183003.py", line 1
#     print(This will cause an error)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("Hello World", end="! ")
print("I will print on the same line.")

# %%
# Print numbers
a=3
print(a)
print(358)
print(500.200)

# %%
#Variables
x = 5
y = "Hello, World!"

print(x)
print(y)

# %%
# Case-Sensitive
a = 4
A = "Sally"

print(a)
print(A)

# %%
#Many Values to Multiple Variables
x, y, z = "Orange", "Banana", "Cherry"

print(x)
print(y)
print(z)

# %%
# Basic Arithmetic Operations
a = 10
b = 5

print("Addition =", a + b)

# %%
print("Subtraction =", a - b)

# %%
print("Multiplication =", a * b)

# %%
print("Division =", a / b)

# %%
# Understanding Data Types
x = 10
y = 3.14
z = "Python"
A = True
C=3+2j

print(type(x))
print(type(y))
print(type(z))
print(type(A))
print(type(C))

# %%
name = input("Enter your name: ")
print("Hello", name)

# %%
#Simple Calculator
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Sum =", a + b)
print("Difference =", a - b)
print("Product =", a * b)
print("Quotient =", a / b)

# %%
# Write a Python program to find the area of a circle.
r = float(input("Enter radius: "))
area = 3.14 * r * r
print("Area of circle =", area)

# %%
# Python Booleans
print(10 > 9)
print(10 == 9)
print(10 < 9)

# %%
# Print a message based on whether the condition is True or False:
a = 200
b = 33

if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
