# %% [markdown]
# <a href="https://colab.research.google.com/github/kshitij-dev16/Python-Lab/blob/main/Practical_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 simple calclator
a = int(input("Enter the value of a : "))
b = int(input("Enter the value of b : "))
print("Addition of a and b is : ",a+b)
print("Subtraction of a and b is : ",a-b)
print("Multiplication of a and b is : ",a*b)
print("Division of a and b is : ",a/b)
print("Modulus of a and b is : ",a%b)
print("Exponent of a and b is : ",a**b)
print("Done")
# Out:
# Enter the value of a : 12
# Enter the value of b : 2
# Addition of a and b is :  14
# Subtraction of a and b is :  10
# Multiplication of a and b is :  24
# Division of a and b is :  6.0
# Modulus of a and b is :  0
# Exponent of a and b is :  144
# Done

# %%
#2 Marks
sum = 0
avg = 0
for i in range(1,6):
    a = int(input("Enter student marks : "))
    sum+=a
print("Averge is ",sum/5)
print("sum is ",sum)
# Out:
# Enter student marks : 35
# Enter student marks : 45
# Enter student marks : 55
# Enter student marks : 66
# Enter student marks : 78
# Averge is  55.8
# sum is  279

# %%
#3 Find area of circle
r = float(input("Enter the radius of circle : "))
print("Area of the given circle is ",3.14*r*r)
# Out:
# Enter the radius of circle : 3
# Area of the given circle is  28.259999999999998

# %%
#4 Find area and perimeter of a rectangle
l = float(input("Enter the length of rectangle : "))
b = float(input("Enter the breadth of rectangle : "))
print("Area of the given rectangle is ",l*b)
print("Perimeter of the given rectangle is ",2*(l+b))
# Out:
# Enter the length of rectangle : 5
# Enter the breadth of rectangle : 7
# Area of the given rectangle is  35.0
# Perimeter of the given rectangle is  24.0
